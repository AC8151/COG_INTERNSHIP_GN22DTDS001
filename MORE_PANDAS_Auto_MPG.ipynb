# %% [markdown]
# <a href="https://colab.research.google.com/github/AC8151/COG_INTERNSHIP_GN22CDBDS001/blob/main/MORE_PANDAS_Auto_MPG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPG Cars
# > By - Aditi Chatterjee

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %%
# https://raw.githubusercontent.com/a-forty-two/COG_GN22CDBDS001_MARCH_22/main/cars1.csv
# https://raw.githubusercontent.com/a-forty-two/COG_GN22CDBDS001_MARCH_22/main/cars2.csv

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
cars1=pd.read_csv('https://raw.githubusercontent.com/a-forty-two/COG_GN22CDBDS001_MARCH_22/main/cars1.csv')
cars2=pd.read_csv('https://raw.githubusercontent.com/a-forty-two/COG_GN22CDBDS001_MARCH_22/main/cars2.csv')

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %%
cars2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# 4       1       amc pacer d/l

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
# dropping unnamed columns.
# drop function works along column (axis=1)
# the change is permanent (inplace=True)
cars1.drop(['Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13'], axis=1, inplace=True)
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.shape[0] # no.of rows in cars1
# Out:
# 198

# %%
cars2.shape[0] # no.of rows in cars2
# Out:
# 200

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
# joining cars1 and cars2 by column (axis=1)
cars = pd.concat([cars1, cars2], axis=1) 
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0        8.0         307.0        130  3504.0          12.0   70.0
# 1  15.0        8.0         350.0        165  3693.0          11.5   70.0
# 2  18.0        8.0         318.0        150  3436.0          11.0   70.0
# 3  16.0        8.0         304.0        150  3433.0          12.0   70.0
# 4  17.0        8.0         302.0        140  3449.0          10.5   70.0
#
#    origin                        car   mpg  cylinders  displacement  \
# 0     1.0  chevrolet chevelle malibu  33.0          4            91
# 1     1.0          buick skylark 320  20.0          6           225
# 2     1.0         plymouth satellite  18.0          6           250
# 3     1.0              amc rebel sst  18.5          6           250
# 4     1.0                ford torino  17.5          6           258
#
#   horsepower  weight  acceleration  model  origin                 car
# ...

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
# random number series called owners created
# has values ranging from 15000 - 73000
# has as many values as the rows of cars dataframe (cars.shape[0])
owners=np.random.randint(15000, 73000, cars.shape[0])

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
# added the numpy series to cars as a new column
cars['owners']=owners 
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0        8.0         307.0        130  3504.0          12.0   70.0
# 1  15.0        8.0         350.0        165  3693.0          11.5   70.0
# 2  18.0        8.0         318.0        150  3436.0          11.0   70.0
# 3  16.0        8.0         304.0        150  3433.0          12.0   70.0
# 4  17.0        8.0         302.0        140  3449.0          10.5   70.0
#
#    origin                        car   mpg  cylinders  displacement  \
# 0     1.0  chevrolet chevelle malibu  33.0          4            91
# 1     1.0          buick skylark 320  20.0          6           225
# 2     1.0         plymouth satellite  18.0          6           250
# 3     1.0              amc rebel sst  18.5          6           250
# 4     1.0                ford torino  17.5          6           258
#
#   horsepower  weight  acceleration  model  origin                 car  owners
# ...

# %% [markdown]
# ###EXTRA. Dropping NULL values

# %%
# finally, removing NULL values from the entire dataset
cars.dropna()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0        8.0         307.0        130  3504.0          12.0   70.0
# 1    15.0        8.0         350.0        165  3693.0          11.5   70.0
# 2    18.0        8.0         318.0        150  3436.0          11.0   70.0
# 3    16.0        8.0         304.0        150  3433.0          12.0   70.0
# 4    17.0        8.0         302.0        140  3449.0          10.5   70.0
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0        6.0         200.0         81  3012.0          17.6   76.0
# 194  22.5        6.0         232.0         90  3085.0          17.6   76.0
# 195  29.0        4.0          85.0         52  2035.0          22.2   76.0
# 196  24.5        4.0          98.0         60  2164.0          22.1   76.0
# 197  29.0        4.0          90.0         70  1937.0          14.2   76.0
#
# ...
